# %% [markdown]
# <a href="https://colab.research.google.com/github/AitorNoel/PontiaProyectoJupiter/blob/main/TP1/02_HeadHunters_x_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import io

# %%
df2 = pd.read_csv('/content/drive/MyDrive/HEADHUNTERS/Headhunter/data/ofertas-empleo (1)(1).csv')
df2.head()
# Out:
#   country_code                                              title  \
# 0           es                      Técnico Gestión de la Demanda
# 1           es  Java - SpringBoot - Proyecto estable - Teletra...
# 2           es            Consultor SAP Hana Ingles Alto (Remoto)
# 3           es        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           es                        Analista Funcional TEMPORAL
#
#                        job_category  \
# 0  Informática y telecomunicaciones
# 1  Informática y telecomunicaciones
# 2  Informática y telecomunicaciones
# 3  Informática y telecomunicaciones
# 4  Informática y telecomunicaciones
#
#                                          description  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
# ...

# %%
df2=df2.drop(['country_code','salary_currency','salary_type','job_category'],axis=1)
display(df2.head(2))

# %%
df2=df2.rename(columns={'title':'titulo','description':'descripcion','company_name':'empresa','city':'ciudad','contract_type':'contrato','salary_period':'sueldo','salary_currency':'divisa','remote':'presencial/remoto','publish_date':'fechaPublicacion'})
df2
