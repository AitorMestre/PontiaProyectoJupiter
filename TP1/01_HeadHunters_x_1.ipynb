# %% [markdown]
# <a href="https://colab.research.google.com/github/AitorNoel/PontiaProyectoJupiter/blob/main/TP1/01_HeadHunters_x_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##EDA##

# %%
import pandas as pd
import numpy as np
import io

# %%
df1 = pd.read_csv('/content/drive/MyDrive/HEADHUNTERS/Headhunter/data/ofertas-de-empleo-sample (1).csv')

# %%
df1.columns
# Out:
# Index(['title', 'description', 'city', 'contract_type', 'workday',
#        'company_name', 'salary_min', 'salary_max', 'salary_period',
#        'salary_currency', 'teleworking', 'publish_date'],
#       dtype='object')

# %%
df1.tail(9)
# Out:
#                                                  title  \
# 391  Carretillero de cámaras con experiencia en man...
# 392                              Mecánico de vehículos
# 393  Consultor/a técnico para gestion ayudas públic...
# 394                                        Camarero /a
# 395                                       JEFE DE OBRA
# 396      Comercial Telefónico / Prospección de Mercado
# 397             ADMINISTRATIVO DEPARTAMENTO DE COMPRAS
# 398                          Beca PRL y Medio Ambiente
# 399                JUNIOR IT - SISTEMAS DE INFORMACION
#
#                                            description  \
# 391  Carretillero de cámaras frigoríficas con forma...
# 392  Buscamos a una persona con conocimientos en me...
# 393  Empresa dedicada a la consultoría en la gestió...
# 394  Jornada completa, turnos seguidos de  8 horas ...
# 395  Empresa constructora especialista en obras del...
# 396  ACEM, SL somos una empresa especializada en la...
# ...

# %%
df1.sample(9)
# Out:
#                                                  title  \
# 146                          MEDICO ADJUNTO GINEOLOGIA
# 34   Auxiliar de Estación de tren con  DISCAPACIDAD...
# 226                                  Profesor Primaria
# 185  Técnico de mecanizado y Ajuste para reparación...
# 383                             EJECUTIVO/A DE CUENTAS
# 101                       Técnico/a Regulatory Affairs
# 385      Nueva plantilla para empresa de Energía Solar
# 69                            Técnico/a Junior Calidad
# 303            ASESOR INMOBILIARIO EN TECNOCASA MADRID
#
#                                            description                   city  \
# 146  En el Hospital Infanta Elena seleccionamos Fac...              Valdemoro
# 34   Grupo empresarial socialmente responsable, pre...                   Elda
# 226  Se necesita profesor de Primaria para colegio ...         Pamplona/Iruña
# 185  Como parte esencial de nuestro equipo de Defen...               Aranjuez
# ...

# %%
df1.dtypes
# Out:
# title               object
# description         object
# city                object
# contract_type       object
# workday             object
# company_name        object
# salary_min         float64
# salary_max         float64
# salary_period       object
# salary_currency     object
# teleworking         object
# publish_date        object
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            400 non-null    object
#  1   description      400 non-null    object
#  2   city             400 non-null    object
#  3   contract_type    400 non-null    object
#  4   workday          400 non-null    object
#  5   company_name     400 non-null    object
#  6   salary_min       159 non-null    float64
#  7   salary_max       146 non-null    float64
#  8   salary_period    159 non-null    object
#  9   salary_currency  159 non-null    object
#  10  teleworking      362 non-null    object
#  11  publish_date     400 non-null    object
# dtypes: float64(2), object(10)
# memory usage: 37.6+ KB

# %%
df1.describe()
# Out:
#          salary_min     salary_max
# count    159.000000     146.000000
# mean   16852.515723   21394.520548
# std    12187.254443   15987.532991
# min      450.000000     600.000000
# 25%    10000.000000    9000.000000
# 50%    18000.000000   21000.000000
# 75%    24000.000000   30000.000000
# max    90000.000000  100000.000000

# %%
df1.plot.scatter("salary_min","salary_max")
# Out:
# <Axes: xlabel='salary_min', ylabel='salary_max'>

# %%
df1[["salary_min","salary_max"]].corr()
# Out:
#             salary_min  salary_max
# salary_min    1.000000    0.902155
# salary_max    0.902155    1.000000

# %% [markdown]
# #1.1 ¿cuántas ofertas hay en el dataset?

# %%
df1.title.count()
# Out:
# 400

# %% [markdown]
# #salario medio

# %%
df1.salary_min.mean().round(2)
# Out:
# 16852.52

# %%
df1.salary_max.mean().round(2)
# Out:
# 21394.52

# %% [markdown]
# #trabajo mejor pagado:

# %%
# Out:
#   File "<ipython-input-18-b228fd038cbe>", line 1
#     df1.{salary_max.max(),title(),description()}
#         ^
# SyntaxError: invalid syntax
