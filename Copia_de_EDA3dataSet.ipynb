# %% [markdown]
# <a href="https://colab.research.google.com/github/AitorNoel/PontiaProyectoJupiter/blob/main/Copia_de_EDA3dataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import nbformat
warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/EDAdfs_(3).csv')

# %% [markdown]
# ##EDA##

# %%
df.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda  hour
# 0             NaN             NaN              NaN    NaN   NaN
# 1        40000.00        45000.00             YEAR    EUR  YEAR
# 2        27000.00        30000.00             YEAR    EUR  YEAR
# 3             NaN             NaN              NaN    NaN   NaN
# 4        24000.00        27000.00             YEAR    EUR  YEAR

# %%
df.shape
# Out:
# (6175, 15)

# %%
# Get the unique values for all columns
unique_values = df.apply(pd.Series.unique)
print(unique_values)
# Out:
# fecha de publicacion    [2022-07-12, 2022-07-11, 2022-08-13, 2022-06-1...
# titulo                  [Técnico Gestión de la Demanda, Java - SpringB...
# descripcion             [-Definición de roles y escenarios\r\n      - ...
# nombre_empresa          [Atento España - Estructura, AGIO GLOBAL TECHN...
# ciudad                  [Madrid, Maresme Central, Getafe, Valencia, Má...
# cod_pais                                                             [es]
# jornada                 [Jornada completa, Jornada indiferente, Jornad...
# tipo de trabajo         [Híbrido, Solo teletrabajo, Presencial, nan, T...
# cluster                 [Informática y telecomunicaciones, Information...
# tipo de contrato        [Contrato indefinido, Contrato otros contratos...
# salario_minimo          [nan, 40000.0, 27000.0, 24000.0, 18000.0, 3000...
# salario_maximo          [nan, 45000.0, 30000.0, 27000.0, 21000.0, 4000...
# periodo salarial                                 [nan, YEAR, MONTH, HOUR]
# moneda                                                         [nan, EUR]
# hour                                             [nan, YEAR, MONTH, HOUR]
# dtype: object

# %%
# Count the number of null values in the entire DataFrame
null_count = df.isnull().sum().sum()
print(null_count)
# Out:
# 23315

# %%
#Value_counts
value_counts = df['titulo'].value_counts()

print(value_counts)
# Out:
# titulo
# Soldador/a                                                              8
# Electromecánico/a                                                       8
# Administrador de Sistemas                                               7
# IT Project Manager                                                      7
# Programador .NET                                                        6
#                                                                        ..
# Beca Energía Solar Fotovoltaica                                         1
# Ingeniero/a de Proyectos e Instalaciones MECÁNICO                       1
# Personal Ingeniería: Eléctrica / Electrónica / Organización / Diseño    1
# Técnico Responsable de Industria 4.0                                    1
# Topógrafo para asistencia ferroviaria en Martorell                      1
# Name: count, Length: 5589, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_titulo = df['titulo'].isnull().sum()

print("Number of null values in column 'titulo':", null_count_titulo)
# Out:
# Number of null values in column 'titulo': 0

# %%
#Value_counts
value_counts = df['periodo salarial'].value_counts()

print(value_counts)
# Out:
# periodo salarial
# YEAR     3074
# MONTH      84
# HOUR        5
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_periodo = df['periodo salarial'].isnull().sum()

print("Number of null values in column 'periodo salarial':", null_count_periodo)
# Out:
# Number of null values in column 'periodo salarial': 3012

# %%
#Value_counts
value_counts = df[['ciudad']].value_counts()

print(value_counts)
# Out:
# ciudad
# Madrid                 2526
# Barcelona              1254
# Sevilla                 157
# Valencia                122
# Zaragoza                 99
#                        ...
# Iurreta                   1
# Idiazabal                 1
# Huévar del Aljarafe       1
# Hoyo de Manzanares        1
# Lorca                     1
# Name: count, Length: 452, dtype: int64

# %%
# Definir las palabras clave que deseas buscar en los títulos
palabras_clave = ['analisis', 'analysis', 'data', 'science', 'product', 'marketing','front','end','analyst','scientist']

# Crear una expresión regular para buscar las palabras clave en los títulos, ignorando mayúsculas y minúsculas
patron = '|'.join(palabras_clave)

# Aplicar la expresión regular a la columna 'title' y obtener los títulos que coinciden
titulos_coincidentes = dfes[dfes['titulo'].str.contains(patron,case=False)]['titulo']

# Obtener los valores únicos de los títulos que coinciden
valores_unicos = titulos_coincidentes.unique()

# Contar la frecuencia de cada título que coincide con las palabras clave
frecuencia_titulos = titulos_coincidentes.value_counts()

# Imprimir los valores únicos y la frecuencia de cada título que coincide con las palabras clave

df_resultado = pd.DataFrame({'Titulo': valores_unicos, 'Frecuencia': frecuencia_titulos})
df_resultado.head(10)
# Out:
#                                                                                                Titulo  \
# titulo
# Product Owner                                                                   PROGRAMADOR FRONT-END
# Consultor/a técnico y desarrollador de Producto...  Big Data Engineer - Technical Support - Google...
# Take UP - Business Analyst Junior con Francés                                   Ruby Backend Engineer
# Agente de Telemarketing Sector Tecnológico                                    Desarrollador Front-end
# Data Engineer                                                             Frontend Developer Angular.
# Data Scientist                                                          TECNICO DATA CENTER - ALMERIA
# Frontend Developer                                                                     Data Architect
# Master Data Analyst                                  Big Data Engineer (AWS) - Compañía Sector Retail
# (Senior) Backend Engineer                           Dependiente/a Tienda Orange - Valencia - Jorna...
# Big Data Engineer - Technical Support - Google ...         Frontend Developer (Angular) - Full Remote
#
#                                                     Frecuencia
# titulo
# Product Owner                                                5
# Consultor/a técnico y desarrollador de Producto...           4
# Take UP - Business Analyst Junior con Francés                4
# Agente de Telemarketing Sector Tecnológico                   4
# Data Engineer                                                4
# Data Scientist                                               4
# Frontend Developer                                           4
# Master Data Analyst                                          3
# (Senior) Backend Engineer                                    3
# Big Data Engineer - Technical Support - Google ...           3

# %%
# Count the number of null values in column 'A'
null_count_ciudad= df['ciudad'].isnull().sum()

print("Number of null values in column 'ciudad':", null_count_ciudad)
# Out:
# Number of null values in column 'ciudad': 1

# %%
#Value_counts
value_counts = df[['cod_pais']].value_counts()

print(value_counts)
# Out:
# cod_pais
# es          6175
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_pais = df['cod_pais'].isnull().sum()

print("Number of null values in column 'cod_pais':", null_count_pais)
# Out:
# Number of null values in column 'cod_pais': 30

# %%
#Value_counts
value_counts = df[['jornada']].value_counts()

print(value_counts)
# Out:
# jornada
# Jornada completa                   4412
# Jornada indiferente                  87
# Jornada intensiva - mañana           63
# Jornada parcial - mañana             36
# Jornada parcial - indiferente        19
# Jornada intensiva - indiferente      16
# Jornada parcial - tarde               7
# Jornada intensiva - tarde             4
# Jornada intensiva - noche             3
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_jornada = df['jornada'].isnull().sum()

print("Number of null values in column 'jornada':", null_count_jornada)
# Out:
# Number of null values in column 'jornada': 5383

# %%
#Value_counts
value_counts = df['tipo de trabajo'].value_counts()

print(value_counts)
# Out:
# tipo de trabajo
# Presencial                 1870
# Híbrido                    1360
# Solo teletrabajo            824
# Trabajo solo presencial     284
# Teletrabajo posible          77
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_tipoTrabajo = df['tipo de trabajo'].isnull().sum()

print("Number of null values in column 'tipo de trabajo':", null_count_tipoTrabajo)
# Out:
# Number of null values in column 'tipo de trabajo': 6015

# %%
#Value_counts
value_counts = df[['nombre_empresa']].value_counts()

print(value_counts)
# Out:
# nombre_empresa
# TD SYNNEX                  110
# Ibermática                  90
# Michael Page                87
# Experis IT                  83
# BETWEEN Technology          81
#                           ...
# Grupo Nova Cartographia      1
# Grupo La Plana               1
# Grupo Kirol                  1
# Grupo Ioe                    1
# vivantadental                1
# Name: count, Length: 1642, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_empresa = df['nombre_empresa'].isnull().sum()

print("Number of null values in column 'nombre_empresa':", null_count_empresa)
# Out:
# Number of null values in column 'nombre_empresa': 0

# %% [markdown]
# ##CASE STUDY QUESTIONS

# %%
#HEAD
df.head(5)
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda  hour
# 0             NaN             NaN              NaN    NaN   NaN
# 1        40000.00        45000.00             YEAR    EUR  YEAR
# 2        27000.00        30000.00             YEAR    EUR  YEAR
# 3             NaN             NaN              NaN    NaN   NaN
# 4        24000.00        27000.00             YEAR    EUR  YEAR

# %%
#tail
df.tail(5)
# Out:
#      fecha de publicacion                                             titulo  \
# 6170           2022-08-08                  Digital Project Consultant Junior
# 6171           2022-03-28                                Electrical Engineer
# 6172           2022-03-28                    Energy Expert Engineer (Remote)
# 6173           2022-03-28  Topógrafo para asistencia ferroviaria en Marto...
# 6174           2022-03-28         Técnico/a de mantenimiento electromecánico
#
#                                             descripcion       nombre_empresa  \
# 6170  High-level knowledge and culture in new digita...                 Atos
# 6171  FERCHAU Spain es la filial independiente del l...        FERCHAU SPAIN
# 6172  As Senior Energy Expert in Digital Operations ...               Huxley
# 6173  Buscamos una persona con la titulación de Inge...  Corporativa - INECO
# 6174  Mantenimiento preventivo y correctivo de maqui...       Robert Walters
#
#                       ciudad cod_pais           jornada  \
# 6170                  Madrid       es               NaN
# 6171       Parets del Vallès       es  Jornada completa
# 6172               Barcelona       es  Jornada completa
# 6173               Martorell       es  Jornada completa
# 6174  Vilafranca del Penedès       es  Jornada completa
#
#               tipo de trabajo                 cluster  \
# 6170                      NaN  Information Technology
# 6171  Trabajo solo presencial   Ingenieros y técnicos
# 6172         Solo teletrabajo   Ingenieros y técnicos
# 6173                      NaN   Ingenieros y técnicos
# 6174  Trabajo solo presencial   Ingenieros y técnicos
#
#               tipo de contrato  salario_minimo  salario_maximo  \
# 6170                       NaN             NaN             NaN
# 6171       Contrato indefinido             NaN             NaN
# 6172       Contrato indefinido             NaN             NaN
# 6173  Contrato otros contratos             NaN             NaN
# 6174       Contrato indefinido        30000.00        36000.00
#
#      periodo salarial moneda  hour
# 6170             YEAR    EUR  YEAR
# 6171              NaN    NaN   NaN
# 6172              NaN    NaN   NaN
# 6173              NaN    NaN   NaN
# 6174             YEAR    EUR  YEAR

# %%
#sample
df.sample(5)
# Out:
#      fecha de publicacion                                             titulo  \
# 5295           2022-08-26  BECARIO/A INGENIERIA QUÍMICA DE OFERTAS Y PROY...
# 2020           2022-06-29  Prácticas CFGS Administración de Sistemas Info...
# 2099           2022-06-29  Técnico Gestor Health, Safety & Environment AR...
# 5663           2022-08-17   Recién titulado/a ingeniería industrial -Madrid-
# 268            2022-07-12               Prácticas Back Office de Operaciones
#
#                                             descripcion  \
# 5295  Empresa de ingeniería medioambiental con exper...
# 2020  ¿Te apasiona el mundo de la tecnología? ¿Te co...
# 2099  Buscamos a una persona con amplios conocimient...
# 5663  ¿Quiénes somos+? Applus+ es una de las empresa...
# 268   En NECSIA IT CONSULTING estamos en búsqueda de...
#
#                      nombre_empresa      ciudad cod_pais  \
# 5295             Keiken Engineering  Alcobendas       es
# 2020  NTT DATA ofertas de prácticas     Sevilla       es
# 2099                       Randstad    Zaragoza       es
# 5663                        Applus+      Madrid       es
# 268                        DEVOTEAM   Barcelona       es
#
#                        jornada   tipo de trabajo  \
# 5295  Jornada parcial - mañana        Presencial
# 2020          Jornada completa           Híbrido
# 2099          Jornada completa        Presencial
# 5663          Jornada completa               NaN
# 268        Jornada indiferente  Solo teletrabajo
#
#                                cluster          tipo de contrato  \
# 5295             Ingenieros y técnicos  Contrato otros contratos
# 2020  Informática y telecomunicaciones        Contrato formativo
# 2099             Ingenieros y técnicos       Contrato indefinido
# 5663             Ingenieros y técnicos        Contrato formativo
# 268   Informática y telecomunicaciones        Contrato formativo
#
#       salario_minimo  salario_maximo periodo salarial moneda  hour
# 5295         6000.00         6000.00             YEAR    EUR  YEAR
# 2020             NaN             NaN              NaN    NaN   NaN
# 2099             NaN             NaN              NaN    NaN   NaN
# 5663             NaN             NaN              NaN    NaN   NaN
# 268              NaN             NaN              NaN    NaN   NaN

# %%
#types
df.dtypes
# Out:
# fecha de publicacion     object
# titulo                   object
# descripcion              object
# nombre_empresa           object
# ciudad                   object
# cod_pais                 object
# jornada                  object
# tipo de trabajo          object
# cluster                  object
# tipo de contrato         object
# salario_minimo          float64
# salario_maximo          float64
# periodo salarial         object
# moneda                   object
# hour                     object
# dtype: object

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6175 entries, 0 to 6174
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fecha de publicacion  6175 non-null   object
#  1   titulo                6175 non-null   object
#  2   descripcion           6175 non-null   object
#  3   nombre_empresa        6175 non-null   object
#  4   ciudad                6174 non-null   object
#  5   cod_pais              6175 non-null   object
#  6   jornada               4647 non-null   object
#  7   tipo de trabajo       4053 non-null   object
#  8   cluster               6175 non-null   object
#  9   tipo de contrato      4647 non-null   object
#  10  salario_minimo        1687 non-null   float64
#  11  salario_maximo        1563 non-null   float64
#  12  periodo salarial      3163 non-null   object
#  13  moneda                3163 non-null   object
#  14  hour                  3163 non-null   object
# dtypes: float64(2), object(13)
# memory usage: 723.8+ KB

# %%
#describe
df.describe()
# Out:
#        salario_minimo  salario_maximo
# count         4445.00         4308.00
# mean         58788.25        83999.69
# std         148664.67       179615.03
# min             12.00           12.00
# 25%          24000.00        30000.00
# 50%          36000.00        46150.00
# 75%          61733.00        91490.25
# max        7500000.00      7501000.00

# %% [markdown]
# #1-¿Cuántas ofertas hay en el dataset?

# %%
#cantidad de ofertas por titulo:
cantidad_ofertas=df[['titulo']].value_counts()
print(cantidad_ofertas)
# Out:
# titulo
# Soldador/a                                                    8
# Electromecánico/a                                             8
# Administrador de Sistemas                                     7
# IT Project Manager                                            7
# QA Tester                                                     6
#                                                              ..
# Entrepreneur + Consultant = Business Builder (all genders)    1
# Enterprise Architect - Partial Remote - Xátiva (Valencia)     1
# Enterprise Account Executive - Spain                          1
# Enterprise Account Executive                                  1
# 全球速卖通事业部(AliExpress) Head of Transport Logistics              1
# Name: count, Length: 5589, dtype: int64

# %%
#cantidad total de ofertas:
cantidad_total_de_ofertas=df.shape[0]
print("el numero total de ofertas es:",cantidad_total_de_ofertas)
# Out:
# el numero total de ofertas es: 10430

# %% [markdown]
# #2-¿Cuál es el salario medio?

# %%
#salario medio:
salario_minimo=df['salario_minimo'].mean()
print(round(salario_minimo))
# Out:
# 26158

# %%
salario_maximo=df['salario_maximo'].mean()
print(round(salario_maximo))
# Out:
# 32438

# %%
salario_medio=(salario_minimo+salario_maximo)/2
print("el salario medio es:",round(salario_medio),"euros")
# Out:
# el salario medio es: 31957 euros

# %%
from scipy.stats import linregress
import matplotlib.pyplot as plt
df['fecha de publicacion']=pd.to_datetime(df['fecha de publicacion'])
df['año_publicacion'] = df['fecha de publicacion'].dt.year
resultado_regresion=linregress(df['salario_maximo'],df['año_publicacion'])
pendiente=resultado_regresion.slope
intercepto=resultado_regresion.intercept
y_regresion=pendiente * df['salario_maximo'] + intercepto
plt.figure(figsize=(12,10))
plt.scatter(df['salario_maximo'], df['año_publicacion'], color='blue', label='Datos originales')
plt.plot(df['salario_maximo'], y_regresion, color='red', label='Línea de regresión')
plt.title('Relación entre salario maximo y año')
plt.xlabel('Salario Maximo')
plt.ylabel('Año')
plt.legend()
plt.show()

# %% [markdown]
# #3-trabajos mejor pagados y donde:

# %%
#trabajo mejor pagado:
indice_max_salario=df['salario_maximo'].idxmax()
trabajo_mejor_pagado=df.loc[indice_max_salario]
print(trabajo_mejor_pagado)
# Out:
# fecha de publicacion                                           2022-07-07
# titulo                                              Country Manager (ESP)
# descripcion             Freedom and responsibility to set the directio...
# nombre_empresa                                                  Hostinger
# ciudad                                                          Barcelona
# cod_pais                                                               es
# jornada                                                               NaN
# tipo de trabajo                                                       NaN
# cluster                                            Information Technology
# tipo de contrato                                                      NaN
# salario_minimo                                                   70000.00
# salario_maximo                                                  100000.00
# periodo salarial                                                     YEAR
# moneda                                                                EUR
# hour                                                                 YEAR
# Name: 667, dtype: object

# %% [markdown]
# #4-tienen los mismos ofertantes ambas fuentes de datos?

# %% [markdown]
# #5-qué empresas publican los mejores salarios?

# %%
#empresas con mejores salarios:
mejores_salarios=df['salario_maximo'].mean()
print(round(mejores_salarios))
# Out:
# 84000

# %%
empresas=df.groupby('nombre_empresa')
filtrado=empresas.filter(lambda x: x['salario_maximo'].sum()>8400)
principales_empresas=df['nombre_empresa'].head()
print(principales_empresas)
# Out:
# 0    Atento España - Estructura
# 1        AGIO GLOBAL TECHNOLOGY
# 2           AIRON Sistemas S.L.
# 3                         MODIS
# 4    Atento España - Estructura
# Name: nombre_empresa, dtype: object

# %%
#donde se demanda mas talento:
lugar_mas_demanda=df['ciudad'].mode()[0]
lugar_mas_demanda
# Out:
# 'Madrid'

# %% [markdown]
# ##EDA TRABAJOS EN ESPAÑA

# %%
##trabajos solo en ESPAÑA:
dfes=df[df['cod_pais'] == 'es']
dfes.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda  hour
# 0             NaN             NaN              NaN    NaN   NaN
# 1        40000.00        45000.00             YEAR    EUR  YEAR
# 2        27000.00        30000.00             YEAR    EUR  YEAR
# 3             NaN             NaN              NaN    NaN   NaN
# 4        24000.00        27000.00             YEAR    EUR  YEAR

# %%
dfes.shape
# Out:
# (6175, 15)

# %%
null_count = dfes.isnull().sum().sum()
print(null_count)
# Out:
# 23315

# %%
dfes['periodo salarial'].unique()
# Out:
# array([nan, 'YEAR', 'MONTH', 'HOUR'], dtype=object)

# %%
dfes['hour']=dfes['periodo salarial'].str.split('-').str[0]
conteo=dfes['hour'].value_counts()
conteo
# Out:
# hour
# YEAR     3074
# MONTH      84
# HOUR        5
# Name: count, dtype: int64

# %%
hourly_titles = dfes.loc[dfes['periodo salarial'] == 'HOUR', 'titulo']
hourly_titles
# Out:
# 1419                           PROGRAMADOR PHP CON INGLÉS
# 3434       Operario/a Alimentación Turnos Rotativos M/T/N
# 7682    Técnico Mantenimiento Industrial - mecánico (d...
# 8768                                 Ingeniero de acopios
# 8973                       Administrativo/a Telemarketing
# Name: titulo, dtype: object

# %%
dfes['periodo salarial'].unique()
# Out:
# array([nan, 'YEAR', 'MONTH', 'HOUR'], dtype=object)

# %%
monthly_titles = dfes.loc[dfes['periodo salarial'] == 'MONTH', 'titulo']
monthly_titles
# Out:
# 30                         MOZO/A ELECTRÓNICO INFORMÁTICO
# 31                              Técnico/a Helpdesk Málaga
# 52                           EUSKALTEL CARREFOUR OIARTZUN
# 117     Técnico/a instalaciones telecomunicaciones en ...
# 211     Técnico de instalaciones de telecomunicaciones...
#                               ...
# 5841                           Beca IT Business Solutions
# 5877                  PRÁCTICAS CONSULTORÍA FUNCIONAL ERP
# 5975                            Comercial botiga Movistar
# 6084                        Maquetador/Diseñador/Creativo
# 6112           Instalador/a de Redes y Telecomunicaciones
# Name: titulo, Length: 84, dtype: object

# %%
hourly_indices = dfes[dfes['periodo salarial'] == 'HOUR'].index
dfes.drop(hourly_indices, inplace=True)
dfes.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda  hour
# 0             NaN             NaN              NaN    NaN   NaN
# 1        40000.00        45000.00             YEAR    EUR  YEAR
# 2        27000.00        30000.00             YEAR    EUR  YEAR
# 3             NaN             NaN              NaN    NaN   NaN
# 4        24000.00        27000.00             YEAR    EUR  YEAR

# %%
monthly_indices = dfes[dfes['periodo salarial'] == 'MONTH'].index
dfes.drop(monthly_indices, inplace=True)
dfes.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda  hour
# 0             NaN             NaN              NaN    NaN   NaN
# 1        40000.00        45000.00             YEAR    EUR  YEAR
# 2        27000.00        30000.00             YEAR    EUR  YEAR
# 3             NaN             NaN              NaN    NaN   NaN
# 4        24000.00        27000.00             YEAR    EUR  YEAR

# %%
dfes['periodo salarial'].unique()
# Out:
# array([nan, 'YEAR'], dtype=object)

# %%
columnas_a_eliminar=['cod_pais','periodo salarial','moneda']
dfes=dfes.drop(columnas_a_eliminar,axis=1)
dfes.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad           jornada   tipo de trabajo  \
# 0  Atento España - Estructura  Madrid  Jornada completa           Híbrido
# 1      AGIO GLOBAL TECHNOLOGY  Madrid  Jornada completa  Solo teletrabajo
# 2         AIRON Sistemas S.L.  Madrid  Jornada completa  Solo teletrabajo
# 3                       MODIS  Madrid  Jornada completa  Solo teletrabajo
# 4  Atento España - Estructura  Madrid  Jornada completa           Híbrido
#
#                             cluster     tipo de contrato  salario_minimo  \
# 0  Informática y telecomunicaciones  Contrato indefinido             NaN
# 1  Informática y telecomunicaciones  Contrato indefinido        40000.00
# 2  Informática y telecomunicaciones  Contrato indefinido        27000.00
# 3  Informática y telecomunicaciones  Contrato indefinido             NaN
# 4  Informática y telecomunicaciones  Contrato indefinido        24000.00
#
#    salario_maximo  hour
# 0             NaN   NaN
# 1        45000.00  YEAR
# 2        30000.00  YEAR
# 3             NaN   NaN
# 4        27000.00  YEAR

# %%
palabras_clave = ['data', 'analyst', 'analista']

# Crea una máscara booleana que indique si cada fila contiene alguna de las palabras clave
mask = dfes['titulo'].str.contains('|'.join(palabras_clave), case=False)

# Filtra el DataFrame utilizando la máscara
resultados = dfes[mask]

# Imprime los resultados
resultados.head()
# Out:
#    fecha de publicacion                                        titulo  \
# 4            2022-07-12                   Analista Funcional TEMPORAL
# 9            2022-07-12                    Analista Funcional / Agile
# 28           2022-07-12  Analista Programador/a Java-Angular (REMOTO)
# 36           2022-07-12         Analista Programador JAVA con Angular
# 60           2022-07-12  Programador/Analista Programador AS400 y RPG
#
#                                           descripcion  \
# 4   Nuevas aplicaciones/Extensión de la funcionali...
# 9   Desde Hasten Group estamos buscando un Analist...
# 28  Sobre Inetum, Positive digital flow\r\n\r\nIne...
# 36  SOTEC Consulting es una compañía de consultorí...
# 60  Nuestra empresa está seleccionando y contratan...
#
#                   nombre_empresa     ciudad cod_pais           jornada  \
# 4     Atento España - Estructura     Madrid       es  Jornada completa
# 9                   Grupo Hasten   Valencia       es  Jornada completa
# 28               INETUM Cataluña  Barcelona       es  Jornada completa
# 36              SOTEC CONSULTING     Madrid       es  Jornada completa
# 60  SERVICIOS UNIFICADOS CATORCE     Madrid       es  Jornada completa
#
#      tipo de trabajo                           cluster     tipo de contrato  \
# 4            Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 9            Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 28  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 36           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 60        Presencial  Informática y telecomunicaciones  Contrato indefinido
#
#     salario_minimo  salario_maximo periodo salarial moneda  hour
# 4         24000.00        27000.00             YEAR    EUR  YEAR
# 9              NaN             NaN              NaN    NaN   NaN
# 28             NaN             NaN              NaN    NaN   NaN
# 36             NaN             NaN              NaN    NaN   NaN
# 60        27000.00        36000.00             YEAR    EUR  YEAR

# %%
palabras_clave = ['data', 'analyst', 'analista']

# Crea una máscara booleana que indique si cada fila contiene alguna de las palabras clave
mask = dfes['titulo'].str.contains('|'.join(palabras_clave), case=False)

# Filtra el DataFrame utilizando la máscara
resultados = dfes[mask]

# Imprime los resultados
ruta_archivo_csv='/content/drive/MyDrive/EDAdfs_(3).csv'
dfes=pd.read_csv(ruta_archivo_csv)
dfes.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda  hour
# 0             NaN             NaN              NaN    NaN   NaN
# 1        40000.00        45000.00             YEAR    EUR  YEAR
# 2        27000.00        30000.00             YEAR    EUR  YEAR
# 3             NaN             NaN              NaN    NaN   NaN
# 4        24000.00        27000.00             YEAR    EUR  YEAR

# %%
# Definir las palabras clave que deseas buscar en los títulos
palabras_clave = ['analisis', 'analysis', 'data', 'science', 'product', 'marketing','front','end','analyst','scientist']

# Crear una expresión regular para buscar las palabras clave en los títulos, ignorando mayúsculas y minúsculas
patron = '|'.join(palabras_clave)

# Aplicar la expresión regular a la columna 'title' y obtener los títulos que coinciden
titulos_coincidentes = dfes[dfes['titulo'].str.contains(patron,case=False)]['titulo']

# Obtener los valores únicos de los títulos que coinciden
valores_unicos = titulos_coincidentes.unique()

# Contar la frecuencia de cada título que coincide con las palabras clave
frecuencia_titulos = titulos_coincidentes.value_counts()

# Imprimir los valores únicos y la frecuencia de cada título que coincide con las palabras clave

df_resultado = pd.DataFrame({'Titulo': valores_unicos, 'Frecuencia': frecuencia_titulos})
df_resultado.head()
# Out:
#                                                                                                Titulo  \
# titulo
# Product Owner                                                                   PROGRAMADOR FRONT-END
# Consultor/a técnico y desarrollador de Producto...  Big Data Engineer - Technical Support - Google...
# Take UP - Business Analyst Junior con Francés                                   Ruby Backend Engineer
# Agente de Telemarketing Sector Tecnológico                                    Desarrollador Front-end
# Data Engineer                                                             Frontend Developer Angular.
#
#                                                     Frecuencia
# titulo
# Product Owner                                                5
# Consultor/a técnico y desarrollador de Producto...           4
# Take UP - Business Analyst Junior con Francés                4
# Agente de Telemarketing Sector Tecnológico                   4
# Data Engineer                                                4

# %%
# Definir las palabras clave que deseas buscar en los títulos
palabras_clave = ['analisis', 'analysis', 'data', 'science', 'product', 'marketing','front','end','analyst','scientist','project manager']

# Crear una expresión regular para buscar las palabras clave en los títulos, ignorando mayúsculas y minúsculas
patron = '|'.join(palabras_clave)

# Aplicar la expresión regular a la columna 'title' y obtener los títulos que coinciden
titulos_coincidentes = dfes[dfes['titulo'].str.contains(patron)]['titulo']

# Obtener los valores únicos de los títulos que coinciden
valores_unicos = titulos_coincidentes.unique()

# Contar la frecuencia de cada título que coincide con las palabras clave
frecuencia_titulos = titulos_coincidentes.value_counts()

# Imprimir los valores únicos y la frecuencia de cada título que coincide con las palabras clave
print("Valores únicos:")
print(valores_unicos)

print("\nFrecuencia de títulos que coinciden con las palabras clave:")
print(frecuencia_titulos)
# Out:
# Valores únicos:
# ['Ruby Backend Engineer' 'Desarrollador Front-end'
#  'Frontend Developer Angular.'
#  'Dependiente/a Tienda Orange - Valencia - Jornada Completa'
#  'Frontend Developer (Angular) - Full Remote'
#  'Dependiente/a comercial tienda Orange - San Sebastián de los Reyes'
#  'Frontend Developers (React)/ Desarrolladores Frontend (React)'
#  'Senior Developer Backend PHP' 'Vendor Relationship Manager'
#  'Progamador Backend PHP' 'Programador Backend (Java o PHP)'
#  'Backend JAVA Developer - Full remote'
#  'Publisher Operations Manager - EMEA (All Genders)'
#  'Senior Front End Developer (2D Rendering-Canvas)'
#  'Tech Lead - Ruby on Rails Backend Engineer (all genders are welcome) RoR - SPAIN'
#  'Desarrollador/a front-end senior'
#  'Programador Backend/Frontend  Java/Javascript en Madrid presencial'
#  'Analista funcional IT (Mercados derivados y productos de inversión) (VE01)'
#  'Ruby on Rails Backend Engineer' 'Desarrollador/a Backend'
#  'Evaluador/a Independiente de Seguridad' 'Backend Prestashop'
#  'Senior Frontend Engineer' 'Frontend AngulaJs developer'
#  'Backend Developer (C++), Amadeus Payments' 'Developer front Angular'
#  'Desarrollador Backend (Teletrabajo100%)'
#  'Frontend Developer - Angular - 100% remote - 50k€'
#  'Frontend Developer - Cloud IONOS Servers' 'Senior Backend Developer'
#  'Desarrollador front-end con ReactJS'
#  'Desarrollador de Front-end con Angular (Remoto)' 'Frontend Developer'
#  'Técnico/a Responsable de Despliegues de equipos de comunicaciones, antenas, radioenlaces, telefonía, datacenters, o sistemas de respaldo eléctrico | Guadarrama'
#  'Ingeniero/a de producto (#)'
#  'Data Scientist / data Architect / Data Engineer (M/F/X)'
#  'Ingeniero/a especialista seguridad contraincendios (HSE) Madrid/Cádiz (:)'
#  'Desarrollador Frontend Javascript  (Teletrabajo 4 años experiencia)'
#  'Junior Backend Developer' 'Junior Frontend Developer'
#  'Desarrollador backend senior .net con experiencia en microservicios'
#  'Gestor/a de proyectos de diseño  e industrialización de productos. Inglés. Móstoles'
#  'Experienced Backend Developer (m/f/d)' '(Senior) Backend Engineer'
#  'Cloud Vendor Operations Analyst'
#  'Senior Python Backend Developer (Barcelona - Hybrid)'
#  'Desarrollador/a Backend Java TELETRABAJO 100% o híbrido a elegir'
#  'Programador/a Backend PHP / Base de dades / Symfony'
#  'Desarrollador Frontend Javascript  (Teletrabajo 4 años experiencia).'
#  'Desarrollador Backend Java' 'Director Consulting (all genders)'
#  'Frontend Developer Angular' 'Senior Frontend Engineer (Remoto)'
#  'Senior Backend Software Engineer' 'Ingeniero/a producto/proceso'
#  'Ingeniero/a de producto. Sector Automoción.'
#  'Agente de Telemarketing Sector Tecnológico'
#  'Senior Frontend developer (React)' 'Developer Frontend'
#  'Senior Frontend Developer' 'Software Engineer Backend'
#  'Analista de datos y tendencias'
#  'Desarrollador JR/SENIOR front-end angular'
#  'Analista funcional y desarrollador/a backend'
#  'Oracle database administrator' 'Backend Developer'
#  'Frontend Developer Angular - Teletrabajo 100%'
#  'Backend Developer-Remoto (/)' 'Desarrollador/a Frontend con Angular'
#  'Desarrollador Senior Backend' 'Programador/a Frontend React  en Remoto'
#  'Arquitecto Frontend (Angular) Mobile (Android/IOS)'
#  'Analistas programadores/as ETL-Talend con Francés'
#  'Frontend Developer (React) (,)'
#  'Frontend Developer (VueJS) - Full Remote'
#  'Analista Desarrollador/a Teradata Exadata #1147'
#  'Desarrollador Junior · Back-end Java #1197'
#  'Senior Python Backend Developer (Remoto)'
#  'Desarrollador/a JUNIOR Frontend.' 'Front-end developer'
#  'Desarrollador/a Junior Java / Big data (Contratación en cliente final)'
#  'Node Backend Cloud Developer - Full Remote'
#  'Frontend React Developer - Full Remote'
#  'Junior Project Manager (all genders)' 'Project Manager (all genders)'
#  'Senior Software Developer -Frontend (d/f/m)'
#  'Frontend Developer (Remoto)'
#  'Vendedor-a / Reponedor-a Carnicería con discapacidad para CARREFOUR Madrid (n)'
#  'Senior Frontend Engineer - Midnight' 'Frontend Tech Lead'
#  'Frontend Engineer Milanuncios'
#  'Entrepreneur + Consultant = Business Builder (all genders)'
#  'Asistente Comercial / Telemarketing en portugués'
#  'Consultor/a en business intelligence y big data'
#  'Senior Frontend Engineer - Core HR (f/m/d)'
#  'Frontend Engineer - Core HR (f/m/d)'
#  'Junior Backend Engineer - Core HR (f/m/d)'
#  'Liferay Front-end / Liferay Back-end.'
#  'Desarrollador/a Frontend (Teletrabajo 100%)'
#  'Desarrollador/a senior Backend ASP.NET CORE'
#  'SWEDISH Technical Support -  (nights, weekends) - Full remote - NEW!'
#  'French Technical Support -  (nights, weekends) - Full remote - NEW!'
#  'Programador Frontend React'
#  'Becario/a de Desarrollo Backend y proyectos de Transformación Digital'
#  'Frontend Developer - VueJS / React / AngularJS'
#  'Frontend Developer (Page technology Services)'
#  'Dependiente/a de Carnicería-Charcutería'
#  'Senior Ruby on Rails Backend Engineer (all genders are welcome) RoR - MADRID / BARCELONA / SPAIN'
#  'Graduate Frontend Engineer, JavaScript/Angular (only EU-based, REMOTE)'
#  'Ingeniero/a Diseño Instalaciones Contraincendio Madrid/Cádiz (:)'
#  'Analista de rendimiento // Multinacional líder renovables'
#  'Implementador/a de sistemas y soluciones de aprendizaje en el entorno laboral'
#  'Técnico de sistemas contra incendios'
#  'Business Analyst (producto) - Scrum - inglés - remoto (*)'
#  'Senior Java Backend Engineers'
#  'Front-end (React) Developer - International Project'
#  'Inspector/a de calidad de productos electrónicos.'
#  'Desarrollador/a Backend .NET CORE'
#  'Graduate Frontend Engineer, JavaScript (REMOTE)'
#  'Vendor Receivable Analyst' 'Software Engineer - Frontend (d/f/m)'
#  'Técnico en Sistemas contra incendios-Naval y terrestre'
#  'Ingeniero/a de Sistemas Contra Incendios'
#  'Desarrollador/a y diseñador/a front con Angular'
#  'Técnico/a Microinformático - La Moraleja (Alcobendas)'
#  'Senior Web Backend Developer (m/f/d)'
#  'Inspector/a de calidad de productos electrónicos'
#  'Técnico Contra Incendios' "Vendors' Data Integrity / PTP Specialist"
#  'Alibaba Group Java Backend Engineer (Logistics) Madrid'
#  'Alibaba Group Java Backend Engineer (Local Brand/ISV) Madrid'
#  'Frontend Developer with React'
#  'Alibaba Group Java Backend Engineer (Local O2O/Digital Goods) Madrid'
#  'Programador Web ( Backend / Frontend)' 'Programador/a Backend con PHP'
#  'INSTALACIÓN DE SISTEMAS DE SEGURIDAD (alarmas y contra incendios) | Barcelona, Girona, Tarragona y alrededores'
#  'Backend developer (Python)'
#  'Frontend Developer Angular/React (Teletrabajo)' 'Desarrollador Frontend'
#  'Programador/a Frontend (JavaScript + Angular )'
#  'Asesor/a Comercial Tienda  ORANGE - SAN SABASTIÁN DE LOS REYES'
#  'Java Backend Developer' 'Dependiente/a Tienda Telefonía. Mollerussa'
#  'Arquitecto Frontend (100% remoto)' 'Administrativo/a Telemarketing'
#  'Senior Java Developer - Backend']
#
# Frecuencia de títulos que coinciden con las palabras clave:
# titulo
# Frontend Developer                                                                     4
# Agente de Telemarketing Sector Tecnológico                                             4
# (Senior) Backend Engineer                                                              3
# Backend JAVA Developer - Full remote                                                   2
# Junior Frontend Developer                                                              2
#                                                                                       ..
# Desarrollador/a Backend Java TELETRABAJO 100% o híbrido a elegir                       1
# Senior Python Backend Developer (Barcelona - Hybrid)                                   1
# Experienced Backend Developer (m/f/d)                                                  1
# Gestor/a de proyectos de diseño  e industrialización de productos. Inglés. Móstoles    1
# Senior Java Developer - Backend                                                        1
# Name: count, Length: 146, dtype: int64

# %% [markdown]
# ##EDA ESPAÑA##

# %%
# Aplicar la expresión regular a la columna 'title' y filtrar el DataFrame original
df_nuevo = dfes[dfes['titulo'].str.contains(patron)]

# Imprimir el nuevo DataFrame
df_nuevo.head(10).reset_index()
# Out:
#    index fecha de publicacion  \
# 0     87           2022-07-12
# 1     88           2022-07-12
# 2     89           2022-07-12
# 3    132           2022-07-12
# 4    154           2022-07-12
# 5    239           2022-07-12
# 6    243           2022-07-12
# 7    269           2022-07-12
# 8    291           2022-07-12
# 9    303           2022-07-12
#
#                                               titulo  \
# 0                              Ruby Backend Engineer
# 1                            Desarrollador Front-end
# 2                        Frontend Developer Angular.
# 3  Dependiente/a Tienda Orange - Valencia - Jorna...
# 4         Frontend Developer (Angular) - Full Remote
# 5  Dependiente/a comercial tienda Orange - San Se...
# 6  Frontend Developers (React)/ Desarrolladores F...
# 7                       Senior Developer Backend PHP
# 8                        Vendor Relationship Manager
# 9                             Progamador Backend PHP
#
#                                          descripcion         nombre_empresa  \
# 0  ¿Eres programador fullstack y trabajas con Rub...  ENTELGY - Zona Madrid
# 1  Desde Fed IT, principal consultora de selecció...                 FED IT
# 2  ¿Eres Desarrollador Angular y te gustaría trab...                 BOYCOR
# 3  Somos importante distribuidor de Orange, actua...                  Oshop
# 4  Somos GeeksHubs y hacemos lo siguiente:\r\n\r\...              Geekshubs
# 5  Somos un distribuidor oficial homologado de Or...                  Oshop
# 6  We are looking for frontend developers with ad...   SD Tech Hub Spain SL
# 7  En Métrica Consulting, empresa de reconocido p...     METRICA CONSULTING
# 8  En Adecco buscamos a un/a Vendor Relationship ...                 ADECCO
# 9  Somos ARATECH, una consultora tecnológica, nac...         Ara Technology
#
#                        ciudad cod_pais                     jornada  \
# 0                      Madrid       es            Jornada completa
# 1                      Madrid       es            Jornada completa
# 2                  Alcobendas       es            Jornada completa
# 3                    Valencia       es            Jornada completa
# 4                      Málaga       es            Jornada completa
# 5  San Sebastián de los Reyes       es            Jornada completa
# 6                   Barcelona       es  Jornada intensiva - mañana
# 7                      Madrid       es            Jornada completa
# 8                      Madrid       es            Jornada completa
# 9       Sant Cugat del Vallès       es            Jornada completa
#
#     tipo de trabajo                           cluster  \
# 0  Solo teletrabajo  Informática y telecomunicaciones
# 1           Híbrido  Informática y telecomunicaciones
# 2  Solo teletrabajo  Informática y telecomunicaciones
# 3        Presencial  Informática y telecomunicaciones
# 4  Solo teletrabajo  Informática y telecomunicaciones
# 5        Presencial  Informática y telecomunicaciones
# 6  Solo teletrabajo  Informática y telecomunicaciones
# 7           Híbrido  Informática y telecomunicaciones
# 8  Solo teletrabajo  Informática y telecomunicaciones
# 9           Híbrido  Informática y telecomunicaciones
#
#                    tipo de contrato  salario_minimo  salario_maximo  \
# 0               Contrato indefinido             NaN             NaN
# 1               Contrato indefinido        24000.00        39000.00
# 2               Contrato indefinido        27000.00        36000.00
# 3               Contrato indefinido             NaN             NaN
# 4               Contrato indefinido        24000.00        27000.00
# 5  Contrato de duración determinada        18000.00        21000.00
# 6               Contrato indefinido        36000.00        50000.00
# 7               Contrato indefinido        33000.00        42000.00
# 8               Contrato indefinido             NaN             NaN
# 9               Contrato indefinido        24000.00        36000.00
#
#   periodo salarial moneda  hour
# 0              NaN    NaN   NaN
# 1             YEAR    EUR  YEAR
# 2             YEAR    EUR  YEAR
# 3              NaN    NaN   NaN
# 4             YEAR    EUR  YEAR
# 5             YEAR    EUR  YEAR
# 6             YEAR    EUR  YEAR
# 7             YEAR    EUR  YEAR
# 8              NaN    NaN   NaN
# 9             YEAR    EUR  YEAR

# %%
df_nuevo.shape
# Out:
# (167, 15)

# %%
value_counts = df_nuevo['nombre_empresa'].value_counts()

print(value_counts)
# Out:
# nombre_empresa
# Geekshubs                             8
# TD SYNNEX                             7
# BETWEEN Technology                    5
# Cocomore AG                           4
# M2C an Ayesa Company                  3
#                                      ..
# Q-TECH                                1
# Randstad                              1
# R & C Associats                       1
# Interactiu Comunicació Digital, SL    1
# DATIVE PARTNERS SOCIEDAD LIMITADA.    1
# Name: count, Length: 111, dtype: int64

# %%
#cantidad de ofertas por titulo:
cantidad_ofertas=df_nuevo['titulo'].value_counts()
print(cantidad_ofertas)
# Out:
# titulo
# Frontend Developer                                                                     4
# Agente de Telemarketing Sector Tecnológico                                             4
# (Senior) Backend Engineer                                                              3
# Backend JAVA Developer - Full remote                                                   2
# Junior Frontend Developer                                                              2
#                                                                                       ..
# Desarrollador/a Backend Java TELETRABAJO 100% o híbrido a elegir                       1
# Senior Python Backend Developer (Barcelona - Hybrid)                                   1
# Experienced Backend Developer (m/f/d)                                                  1
# Gestor/a de proyectos de diseño  e industrialización de productos. Inglés. Móstoles    1
# Senior Java Developer - Backend                                                        1
# Name: count, Length: 146, dtype: int64

# %%
cantidad_total_de_ofertas=df_nuevo.shape[0]
print("el numero total de ofertas es:",cantidad_total_de_ofertas)
# Out:
# el numero total de ofertas es: 167

# %%
#salario minimo:
salario_minimo=df_nuevo['salario_minimo'].mean()
print(round(salario_minimo))
# Out:
# 27733

# %%
#salario maximo:
salario_maximo=df_nuevo['salario_maximo'].mean()
print(round(salario_maximo))
# Out:
# 36181

# %%
#salario medio
salario_medio=(salario_minimo+salario_maximo)/2
print("el salario medio es:",round(salario_medio),"euros")
# Out:
# el salario medio es: 33071 euros

# %%
5#empresas que publican los mejores salarios, por encima de la media
empresas=df_nuevo.groupby('nombre_empresa')
filtrado=empresas.filter(lambda x: x['salario_maximo'].sum()>33071)
principales_empresas=df['nombre_empresa'].head()
print(principales_empresas)
# Out:
# 0    Atento España - Estructura
# 1        AGIO GLOBAL TECHNOLOGY
# 2           AIRON Sistemas S.L.
# 3                         MODIS
# 4    Atento España - Estructura
# Name: nombre_empresa, dtype: object

# %%
#trabajo mejor pagado:
indice_max_salario=df_nuevo['salario_maximo'].idxmax()
trabajo_mejor_pagado=df.loc[indice_max_salario]
print(trabajo_mejor_pagado)
# Out:
# fecha de publicacion                                           2022-07-04
# titulo                      Frontend Developer Angular - Teletrabajo 100%
# descripcion             Desde AgioGlobal Technology, nos encontramos e...
# nombre_empresa                                     AGIO GLOBAL TECHNOLOGY
# ciudad                                                             Madrid
# cod_pais                                                               es
# jornada                                                  Jornada completa
# tipo de trabajo                                          Solo teletrabajo
# cluster                                  Informática y telecomunicaciones
# tipo de contrato                                      Contrato indefinido
# salario_minimo                                                   50000.00
# salario_maximo                                                   60000.00
# periodo salarial                                                     YEAR
# moneda                                                                EUR
# hour                                                                 YEAR
# Name: 3008, dtype: object

# %%
df_nuevo.head()
# Out:
#     fecha de publicacion                                             titulo  \
# 87            2022-07-12                              Ruby Backend Engineer
# 88            2022-07-12                            Desarrollador Front-end
# 89            2022-07-12                        Frontend Developer Angular.
# 132           2022-07-12  Dependiente/a Tienda Orange - Valencia - Jorna...
# 154           2022-07-12         Frontend Developer (Angular) - Full Remote
#
#                                            descripcion         nombre_empresa  \
# 87   ¿Eres programador fullstack y trabajas con Rub...  ENTELGY - Zona Madrid
# 88   Desde Fed IT, principal consultora de selecció...                 FED IT
# 89   ¿Eres Desarrollador Angular y te gustaría trab...                 BOYCOR
# 132  Somos importante distribuidor de Orange, actua...                  Oshop
# 154  Somos GeeksHubs y hacemos lo siguiente:\r\n\r\...              Geekshubs
#
#          ciudad cod_pais           jornada   tipo de trabajo  \
# 87       Madrid       es  Jornada completa  Solo teletrabajo
# 88       Madrid       es  Jornada completa           Híbrido
# 89   Alcobendas       es  Jornada completa  Solo teletrabajo
# 132    Valencia       es  Jornada completa        Presencial
# 154      Málaga       es  Jornada completa  Solo teletrabajo
#
#                               cluster     tipo de contrato  salario_minimo  \
# 87   Informática y telecomunicaciones  Contrato indefinido             NaN
# 88   Informática y telecomunicaciones  Contrato indefinido        24000.00
# 89   Informática y telecomunicaciones  Contrato indefinido        27000.00
# 132  Informática y telecomunicaciones  Contrato indefinido             NaN
# 154  Informática y telecomunicaciones  Contrato indefinido        24000.00
#
#      salario_maximo periodo salarial moneda  hour
# 87              NaN              NaN    NaN   NaN
# 88         39000.00             YEAR    EUR  YEAR
# 89         36000.00             YEAR    EUR  YEAR
# 132             NaN              NaN    NaN   NaN
# 154        27000.00             YEAR    EUR  YEAR

# %%
dfes.to_csv('EDAdfs.csv',index=False)

# %% [markdown]
# #
