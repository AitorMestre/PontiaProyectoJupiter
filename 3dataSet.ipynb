# %% [markdown]
# <a href="https://colab.research.google.com/github/AitorNoel/PontiaProyectoJupiter/blob/main/3dataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import io
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/3dataSet.csv')

# %%
df.head()
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda
# 0             NaN             NaN              NaN    NaN
# 1        40000.00        45000.00             YEAR    EUR
# 2        27000.00        30000.00             YEAR    EUR
# 3             NaN             NaN              NaN    NaN
# 4        24000.00        27000.00             YEAR    EUR

# %%
df.shape
# Out:
# (10430, 14)

# %%
# Get the unique values for all columns
unique_values = df.apply(pd.Series.unique)
print(unique_values)
# Out:
# fecha de publicacion    [2022-07-12, 2022-08-26, 2022-09-02, 2022-09-0...
# titulo                  [Técnico Gestión de la Demanda, Java - SpringB...
# descripcion             [-Definición de roles y escenarios\r\n      - ...
# nombre_empresa          [Atento España - Estructura, AGIO GLOBAL TECHN...
# ciudad                  [Madrid, Maresme Central, Getafe, Valencia, Má...
# cod_pais                [es, us, sg, de, nl, uk, in, fr, mx, ie, ES, nan]
# jornada                 [Jornada completa, nan, Jornada indiferente, J...
# tipo de trabajo         [Híbrido, Solo teletrabajo, Presencial, nan, T...
# cluster                 [Informática y telecomunicaciones, Management ...
# tipo de contrato        [Contrato indefinido, Contrato otros contratos...
# salario_minimo          [nan, 40000.0, 27000.0, 24000.0, 18000.0, 3000...
# salario_maximo          [nan, 45000.0, 30000.0, 27000.0, 21000.0, 4000...
# periodo salarial                                 [nan, YEAR, MONTH, HOUR]
# moneda                           [nan, EUR, USD, SGD, GBP, INR, MXN, IRR]
# dtype: object

# %%
# Count the number of null values in the entire DataFrame
null_count = df.isnull().sum().sum()
print(null_count)
# Out:
# 35885

# %%
#Value_counts
value_counts = df['titulo'].value_counts()

print(value_counts)
# Out:
# titulo
# Project Manager                                            22
# Software Engineer                                          14
# Business Analyst                                           13
# Data Analyst                                               12
# Security Officer                                           10
#                                                            ..
# INGENIERO/A RESPONSABLE MANTENIMIENTO                       1
# Electromecánico Industrial alimentación- Sevilla            1
# Mecánico industrial                                         1
# TECNICO/A DE DOCUMENTACIÓN GRAFICA_GIS                      1
# Business Analyst - Private Equity & Principal Investors     1
# Name: count, Length: 9236, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_titulo = df['titulo'].isnull().sum()

print("Number of null values in column 'titulo':", null_count_titulo)
# Out:
# Number of null values in column 'titulo': 0

# %%
#Value_counts
value_counts = df['periodo salarial'].value_counts()

print(value_counts)
# Out:
# periodo salarial
# YEAR     7024
# MONTH     118
# HOUR        5
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_periodo = df['periodo salarial'].isnull().sum()

print("Number of null values in column 'periodo salarial':", null_count_periodo)
# Out:
# Number of null values in column 'periodo salarial': 3283

# %%
#Value_counts
value_counts = df['ciudad'].value_counts()

print(value_counts)
# Out:
# ciudad
# Madrid                   2625
# Barcelona                1292
# London, England           566
# Singapore                 553
# Austin, TX                291
#                          ...
# Iurreta                     1
# Lobón                       1
# Avinyó                      1
# Macael                      1
# Camarma de Esteruelas       1
# Name: count, Length: 550, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_ciudad= df['ciudad'].isnull().sum()

print("Number of null values in column 'ciudad':", null_count_ciudad)
# Out:
# Number of null values in column 'ciudad': 1

# %%
#Value_counts
value_counts = df['cod_pais'].value_counts()

print(value_counts)
# Out:
# cod_pais
# es    6175
# us    1264
# uk     857
# sg     553
# ES     400
# de     368
# fr     335
# in     203
# nl     136
# ie      99
# mx      10
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_pais = df['cod_pais'].isnull().sum()

print("Number of null values in column 'cod_pais':", null_count_pais)
# Out:
# Number of null values in column 'cod_pais': 30

# %%
#Value_counts
value_counts = df['jornada'].value_counts()

print(value_counts)
# Out:
# jornada
# Jornada completa                   4756
# Jornada indiferente                 108
# Jornada intensiva - mañana           69
# Jornada parcial - mañana             42
# Jornada intensiva - indiferente      28
# Jornada parcial - indiferente        27
# Jornada parcial - tarde               9
# Jornada intensiva - tarde             5
# Jornada intensiva - noche             3
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_jornada = df['jornada'].isnull().sum()

print("Number of null values in column 'jornada':", null_count_jornada)
# Out:
# Number of null values in column 'jornada': 5383

# %%
#Value_counts
value_counts = df['tipo de trabajo'].value_counts()

print(value_counts)
# Out:
# tipo de trabajo
# Presencial                 1870
# Híbrido                    1360
# Solo teletrabajo            824
# Trabajo solo presencial     284
# Teletrabajo posible          77
# Name: count, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_tipoTrabajo = df['tipo de trabajo'].isnull().sum()

print("Number of null values in column 'tipo de trabajo':", null_count_tipoTrabajo)
# Out:
# Number of null values in column 'tipo de trabajo': 6015

# %%
#Value_counts
value_counts = df['nombre_empresa'].value_counts()

print(value_counts)
# Out:
# nombre_empresa
# Michael Page                       139
# Turner & Townsend                  136
# TD SYNNEX                          129
# Accenture                          128
# Apple                              111
#                                   ...
# ARTHUR D. LITTLE ASIA PTE. LTD.      1
# AJ RESOURCES PTE. LTD.               1
# Amazon Kuiper Manufacturing          1
# Ntirety                              1
# Cobee                                1
# Name: count, Length: 3138, dtype: int64

# %%
# Count the number of null values in column 'A'
null_count_empresa = df['nombre_empresa'].isnull().sum()

print("Number of null values in column 'nombre_empresa':", null_count_empresa)
# Out:
# Number of null values in column 'nombre_empresa': 0

# %% [markdown]
# ##EDA##

# %%
#HEAD
df.head(5)
# Out:
#   fecha de publicacion                                             titulo  \
# 0           2022-07-12                      Técnico Gestión de la Demanda
# 1           2022-07-12  Java - SpringBoot - Proyecto estable - Teletra...
# 2           2022-07-12            Consultor SAP Hana Ingles Alto (Remoto)
# 3           2022-07-12        ANDROID DEVELOPER. INGLÉS ALTO. 100% REMOTO
# 4           2022-07-12                        Analista Funcional TEMPORAL
#
#                                          descripcion  \
# 0  -Definición de roles y escenarios\r\n      - D...
# 1  Desde AgioGlobal Technology, nos encontramos e...
# 2  AirON compañia de innovacion servicios tecnolo...
# 3  Desde MODIS IT consultora GLOBAL especializada...
# 4  Nuevas aplicaciones/Extensión de la funcionali...
#
#                nombre_empresa  ciudad cod_pais           jornada  \
# 0  Atento España - Estructura  Madrid       es  Jornada completa
# 1      AGIO GLOBAL TECHNOLOGY  Madrid       es  Jornada completa
# 2         AIRON Sistemas S.L.  Madrid       es  Jornada completa
# 3                       MODIS  Madrid       es  Jornada completa
# 4  Atento España - Estructura  Madrid       es  Jornada completa
#
#     tipo de trabajo                           cluster     tipo de contrato  \
# 0           Híbrido  Informática y telecomunicaciones  Contrato indefinido
# 1  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 2  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 3  Solo teletrabajo  Informática y telecomunicaciones  Contrato indefinido
# 4           Híbrido  Informática y telecomunicaciones  Contrato indefinido
#
#    salario_minimo  salario_maximo periodo salarial moneda
# 0             NaN             NaN              NaN    NaN
# 1         40000.0         45000.0             YEAR    EUR
# 2         27000.0         30000.0             YEAR    EUR
# 3             NaN             NaN              NaN    NaN
# 4         24000.0         27000.0             YEAR    EUR

# %%
#tail
df.tail(5)
# Out:
#            fecha de publicacion  \
# 10425  2022-08-22T00:00:00.000Z
# 10426  2022-01-26T00:00:00.000Z
# 10427  2022-10-19T00:00:00.000Z
# 10428  2023-01-23T00:00:00.000Z
# 10429  2022-04-06T00:00:00.000Z
#
#                                                   titulo  \
# 10425     Graduate Program INTERNATIONAL FINANCE ANALYST
# 10426                             Analyst - GeoAnalytics
# 10427                             Data Labelling (Spain)
# 10428                                       Data Analyst
# 10429  Business Analyst - Private Equity & Principal ...
#
#                                              descripcion  \
# 10425  Agency :\nHavas Media Group Spain\nJob Descrip...
# 10426  WHAT YOU'LL DO\nGAMMA is BCG’s premier data sc...
# 10427  We are a leading digital identity company that...
# 10428  About Us & Our Culture\nWe, employees, need a ...
# 10429  Who You'll Work With\nYou will be based in our...
#
#                 nombre_empresa  ciudad cod_pais jornada tipo de trabajo  \
# 10425              Havas Group  Madrid      NaN     NaN             NaN
# 10426  Boston Consulting Group  Madrid      NaN     NaN             NaN
# 10427      Incode Technologies  Madrid      NaN     NaN             NaN
# 10428                    Cobee  Madrid      NaN     NaN             NaN
# 10429       McKinsey & Company  Madrid      NaN     NaN             NaN
#
#       cluster tipo de contrato  salario_minimo  salario_maximo  \
# 10425     NaN              NaN             NaN             NaN
# 10426     NaN              NaN             NaN             NaN
# 10427     NaN              NaN             NaN             NaN
# 10428     NaN              NaN             NaN             NaN
# 10429     NaN              NaN             NaN             NaN
#
#       periodo salarial moneda
# 10425              NaN    EUR
# 10426              NaN    EUR
# 10427              NaN    EUR
# 10428              NaN    EUR
# 10429              NaN    EUR

# %%
#sample
df.sample(5)
# Out:
#      fecha de publicacion                                    titulo  \
# 5434           2022-07-22                     Arquitecto soluciones
# 3166           2022-06-28  Técnico Auxiliar Laboratorio Electrónico
# 8504           2022-08-25                        Planner - Aviation
# 4877           2022-08-06  INGENIERO/A DE MEJORA CONTINUA. HERENCIA
# 9357           2022-08-30           Business Analyst Salesforce H/F
#
#                                             descripcion  \
# 5434  La colaboración es clave en el desarrollo de n...
# 3166  Si tienes formación en el ámbito de la electró...
# 8504  P6 schedule development and administration, de...
# 4877  Avanza Externalización de Servicios S.A selecc...
# 9357  Pour ce faire, nous intervenons sur l’ensemble...
#
#                     nombre_empresa              ciudad cod_pais  \
# 5434                     Capgemini           Barcelona       es
# 3166                       INELCOM  Pozuelo de Alarcón       es
# 8504             Turner & Townsend     London, England       uk
# 4877  Avanza Outsourcing Solutions            Herencia       es
# 9357                SIRIS ADVISORY               Paris       fr
#
#                jornada tipo de trabajo                  cluster  \
# 5434               NaN             NaN   Information Technology
# 3166  Jornada completa      Presencial    Ingenieros y técnicos
# 8504               NaN             NaN  Management & Consulting
# 4877  Jornada completa             NaN    Ingenieros y técnicos
# 9357               NaN             NaN  Management & Consulting
#
#               tipo de contrato  salario_minimo  salario_maximo  \
# 5434                       NaN             NaN             NaN
# 3166  Contrato otros contratos         18000.0         18000.0
# 8504                       NaN         52116.0         66541.0
# 4877       Contrato indefinido         24000.0         33000.0
# 9357                       NaN         50000.0         61000.0
#
#      periodo salarial moneda
# 5434             YEAR    EUR
# 3166             YEAR    EUR
# 8504             YEAR    GBP
# 4877             YEAR    EUR
# 9357             YEAR    EUR

# %%
#types
df.dtypes
# Out:
# fecha de publicacion     object
# titulo                   object
# descripcion              object
# nombre_empresa           object
# ciudad                   object
# cod_pais                 object
# jornada                  object
# tipo de trabajo          object
# cluster                  object
# tipo de contrato         object
# salario_minimo          float64
# salario_maximo          float64
# periodo salarial         object
# moneda                   object
# dtype: object

# %%
#info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10430 entries, 0 to 10429
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fecha de publicacion  10430 non-null  object
#  1   titulo                10430 non-null  object
#  2   descripcion           10430 non-null  object
#  3   nombre_empresa        10430 non-null  object
#  4   ciudad                10429 non-null  object
#  5   cod_pais              10400 non-null  object
#  6   jornada               5047 non-null   object
#  7   tipo de trabajo       4415 non-null   object
#  8   cluster               10000 non-null  object
#  9   tipo de contrato      5047 non-null   object
#  10  salario_minimo        4445 non-null   float64
#  11  salario_maximo        4308 non-null   float64
#  12  periodo salarial      7147 non-null   object
#  13  moneda                7177 non-null   object
# dtypes: float64(2), object(12)
# memory usage: 1.1+ MB

# %%
#describe
df.describe()
# Out:
#        salario_minimo  salario_maximo
# count    4.445000e+03    4.308000e+03
# mean     5.878825e+04    8.399969e+04
# std      1.486647e+05    1.796150e+05
# min      1.200000e+01    1.200000e+01
# 25%      2.400000e+04    3.000000e+04
# 50%      3.600000e+04    4.615000e+04
# 75%      6.173300e+04    9.149025e+04
# max      7.500000e+06    7.501000e+06

# %%
#salario minimo y maximo
df[["salario_minimo","salario_maximo"]].corr()
# Out:
#                 salario_minimo  salario_maximo
# salario_minimo            1.00            0.96
# salario_maximo            0.96            1.00

# %%
plt.figure(figsize=(20,4))
plt.plot(df['salario_maximo'],df['fecha de publicacion'],
         color='black',
         linewidth=3,
         marker='o')

plt.xlabel('salario_maximo')
plt.ylabel('fecha de publicacion')
plt.show;
